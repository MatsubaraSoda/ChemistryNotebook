# %% [markdown]
# # 固体和现代材料

# %% [markdown]
# [Crystallographic Resources at Otterbein University](https://crystals.symotter.org/)

# %% [markdown]
# ## 固体分类
#
# 金属固体 (Metallic solids)
#
# 离子固体 (Ionic solids)
#
# 共价网络固体 (Covalent-network solids)
#
# 分子固体 (Molecular solids)
#
# 聚合物 (Polymers)
#
# 纳米材料 (Nanomaterials)
#
#
# ![Classification and examples of solids according to predominant bonding type.](./fig-12-1.svg)

# %% [markdown]
# ## 结构和堆积
#
# **Simple Cubic** or **Primitive Cubic**
#
# $$
# \frac{\pi}{6} \approx 52.36 \%
# $$
#
# **Body-Centered Cubic**
#
# $$
# \frac{\sqrt{3} \pi}{8} \approx 68.02 \%
# $$
#
# **Face-Centered Cubic** or **Cubic close-packed**
#
# $$
# \frac{\sqrt{2} \,\pi}{6} \approx 74.05 \%
# $$
#
# **Hexagonal close-packed**
#
# $$
# \approx 74.05 \%
# $$
#
# ![The structures of (a) primitive cubic, (b) body-centered cubic, and (c) facecentered cubic metals.](./fig-12-11.svg)
#
# ![A space-filling view of unit cells for metals with a cubic structure.](./fig-12-12.svg)

# %% [markdown]
# ## 合金
#
# 置换合金 (Substitutional alloys)
#
# 间隙合金 (Interstitial alloys)
#
# 异质合金 (Heteroatomic alloys)
#
# 金属间化合物 (Intermetallic compounds)

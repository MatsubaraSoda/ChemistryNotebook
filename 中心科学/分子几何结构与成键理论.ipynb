# %% [markdown]
# # 分子几何结构与成键理论

# %% [markdown]
# ## VSEPR 模型
#
# 适用范围：
#
# - 主族元素
# - 共价化合物
#
# ![Electron-Domain Geometries as a Function of Number of Electron Domains](./table-9-1.svg)
#
# ![Electron-Domain and Molecular Geometries for Two, Three, and Four Electron Domains around a Central Atom](./table-9-2.svg)
#
# ![Electron-Domain and Molecular Geometries for Five and Six Electron Domains around a Central Atom](./table-9-3.svg)

# %% [markdown]
# ## 共价键和轨道重叠
#
# ![Covalent bonds in H2, HCl, and Cl2 result from overlap of atomic orbitals](./fig-9-13.svg)

# %% [markdown]
# ## 杂化轨道
#
# Hybrid Orbitals
#
# 适用范围：
#
# - 有机化学
#
# ![Formation of sp hybrid orbitals.](./fig-9-15.svg)
#
# ![Geometric Arrangements Characteristic of Hybrid Orbital Sets](./table-9-4.svg)

# %% [markdown]
# ## 多重键
#
# Multiple Bonds
#
# ![Comparison of σ and π bonds.](./fig-9-21.svg)
#
# ### C2H4
#
# ![The orbital structure of ethylene, C2H4.](./fig-9-23.svg)
#
# ### C2H2
#
# ![Formation of two σ bonds in acetylene, C2H2.](./fig-9-24.svg)
#
# ### Benzene
#
# ![Delocalized π bonds in benzene.](./fig-9-27.svg)

# %% [markdown]
# ## 分子轨道
#
# Molecular Orbitals (MO)
#
# ### 第二周期元素
#
# ![Energy-level diagram for MOs of period 2 homonuclear diatomic molecules.](./fig-9-41.png)
#
# ![Molecular orbital electron configurations and some experimental data for period 2 diatomic molecules.](./fig-9-43.svg)
#
# ### NO
#
# ![The energy-level diagram for atomic and molecular orbitals in NO.](./fig-9-46.svg)

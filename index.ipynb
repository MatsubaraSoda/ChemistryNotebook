# %% [markdown]
# # 化学笔记
#
# ::: {.home-hero}
# 个人学习笔记站点，随读 **Brown、LeMay** 等所著 *Chemistry: The Central Science*（《化学：中心科学》）而整理：公式推导、图示复现、小结与延伸演算。
# :::
#
# ## 快速进入 · 中心科学
#
# ::: {.home-nav-grid}
#
# ::: {.home-card}
# #### 章节笔记
#
# 按教材章节整理的笔记与图示，从基础知识到酸碱平衡；完整目录见左侧边栏。文末附有周期表、轨道可视化等常用在线工具。
#
# [从「基础知识」开始](中心科学/基础知识.ipynb){.home-card-link}
# :::
#
# ::: {.home-card}
# #### 小结与演算
#
# 实验模拟、模型推导与专题延伸——如酸碱滴定、玻尔模型、查普曼循环臭氧分布等。
#
# [浏览小结](中心科学/小结/热化学方程式.ipynb){.home-card-link}
# :::
#
# :::
#
# ## 所用教材
#
# | 项目 | 内容 |
# | :--- | :--- |
# | **书名（英文）** | *Chemistry: The Central Science* |
# | **中文常用名** | 《化学：中心科学》 |
# | **版本** | **第 13 版（Thirteenth Edition）**，**Global Edition（全球版）** |
# | **作者** | Theodore L. Brown；H. Eugene LeMay, Jr.；Bruce E. Bursten；Catherine J. Murphy；Patrick M. Woodward；Matthew W. Stoltzfus |
# | **出版社** | Pearson Education Limited（全球版）；改编自美国版 Pearson Education |
# | **出版年** | **© 2015**（版权页） |
# | **语言** | English |
# | **ISBN-10** | 1-292-05771-8 |
# | **ISBN-13**| 978-1-292-05771-2 (Print) <br/> 978-1-292-06725-4 (PDF) |
